# %% [markdown]
# # Installation

# %%
pip install openai python-dotenv
# Out:
# Collecting openai
#   Downloading openai-1.76.0-py3-none-any.whl.metadata (25 kB)
# Collecting python-dotenv
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/yola.kamalita/anaconda3/envs/self_learning_projects/lib/python3.9/site-packages (from openai) (4.2.0)
# Collecting distro<2,>=1.7.0 (from openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.9.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/yola.kamalita/anaconda3/envs/self_learning_projects/lib/python3.9/site-packages (from openai) (2.8.2)
# Requirement already satisfied: sniffio in /Users/yola.kamalita/anaconda3/envs/self_learning_projects/lib/python3.9/site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /Users/yola.kamalita/anaconda3/envs/self_learning_projects/lib/python3.9/site-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/yola.kamalita/anaconda3/envs/self_learning_projects/lib/python3.9/site-packages (from openai) (4.11.0)
# Requirement already satisfied: idna>=2.8 in /Users/yola.kamalita/anaconda3/envs/self_learning_projects/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/yola.kamalita/anaconda3/envs/self_learning_projects/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Requirement already satisfied: certifi in /Users/yola.kamalita/anaconda3/envs/self_learning_projects/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/yola.kamalita/anaconda3/envs/self_learning_projects/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /Users/yola.kamalita/anaconda3/envs/self_learning_projects/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)
# Downloading openai-1.76.0-py3-none-any.whl (661 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 661.2/661.2 kB 5.9 MB/s eta 0:00:0000:0100:01
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 4.4 MB/s eta 0:00:00
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 5.5 MB/s eta 0:00:00
# Downloading jiter-0.9.0-cp39-cp39-macosx_11_0_arm64.whl (312 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 312.6/312.6 kB 8.4 MB/s eta 0:00:00
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Installing collected packages: python-dotenv, jiter, h11, distro, httpcore, httpx, openai
# Successfully installed distro-1.9.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 jiter-0.9.0 openai-1.76.0 python-dotenv-1.1.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Set up API Key

# %%
from openai import OpenAI
import os
from dotenv import load_dotenv

# Load environment variables from a .env file
load_dotenv()

client = OpenAI(
    api_key=os.environ.get("OPENAI_API_KEY"),
)

# %% [markdown]
# # Prompt Engineering

# %% [markdown]
# ## Zero-Shot Prompting

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "user", "content": "What is the best marketing technique for tech companies?"},  
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# The best marketing technique for tech companies often depends on their specific products, target audience, and market conditions. However, several effective strategies are commonly used in the tech industry:
#
# 1. **Content Marketing**: Creating valuable content that educates and informs potential customers can build trust and establish authority. This includes blogs, whitepapers, case studies, webinars, and videos that highlight product benefits and industry trends.
#
# 2. **Search Engine Optimization (SEO)**: Optimizing online content for search engines ensures that potential customers can find your products and services when searching for relevant keywords and topics.
#
# 3. **Social Media Marketing**: Utilizing platforms like LinkedIn, Twitter, and Facebook to share content, engage with customers, and promote products helps to build community and brand awareness.
#
# 4. **Email Marketing**: Targeting existing customers and leads with personalized email content can nurture relationships, inform about product updates, and drive conversions.
#
# 5. **Influencer Marketing**: Partnering with industry influencers or thought leaders can enhance credibility and reach a broader audience, especially if they're trusted voices in the tech community.
#
# 6. **Demonstrations and Webinars**: Offering live demos, webinars, or free trials of your product can help potential customers understand its value and functionality.
#
# 7. **Customer Testimonials and Case Studies**: Showcasing real-world applications and success stories can greatly influence potential buyers by illustrating how your tech solutions solve specific problems.
#
# 8. **Paid Advertising**: Pay-per-click (PPC) campaigns, display ads, and social media advertising can drive targeted traffic to your website and generate leads quickly.
#
# 9. **Community Engagement**: Building a community around your product through forums, user groups, or developer communities can foster loyalty and encourage word-of-mouth marketing.
#
# 10. **Retention Marketing**: Focusing on retaining existing customers through loyalty programs, regular check-ins, and personalized communication can lead to repeat business and referrals.
#
# Tech companies often benefit from a combination of these techniques, tailored to their specific goals and audiences. Continuous analysis of marketing performance and adapting strategies based on data-driven insights is also crucial for long-term success.

# %% [markdown]
# ## One-Shot Prompting

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "user", "content": "Example: What is This is April?"},
        {"role": "assistant", "content": "This is April is a retail company from Indonesia."},
        {"role": "user", "content": "What is H&M?"}
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# H&M, or Hennes & Mauritz, is a Swedish multinational clothing retail company known for its fast-fashion apparel. Founded in 1947, H&M offers a wide range of products, including clothing, accessories, and footwear for men, women, teenagers, and children. The brand is recognized for its trendy designs at affordable prices, and it operates thousands of stores worldwide, as well as an online shopping platform. H&M emphasizes sustainability and has initiatives aimed at reducing environmental impact and promoting ethical fashion.

# %% [markdown]
# ## Few-Shot Prompting

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "user", "content": "Example: What is This is April?"},
        {"role": "assistant", "content": "This is April is a retail company from Indonesia."},
        {"role": "user", "content": "What is H&M?"},
        {"role": "assistant", "content": "H&M is a retail company from Swedia."},
        {"role": "user", "content": "What is Mango?"},
        {"role": "assistant", "content": "Mango is a retail company from Spain."},
        {"role": "user", "content": "What is Adidas?"},
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# Adidas is a global sportswear and lifestyle brand based in Germany. Founded in 1949 by Adolf Dassler, the company is known for its athletic footwear, apparel, and equipment. Adidas is recognized for its iconic three-stripe logo and has become one of the leading brands in the sports and fashion industries, catering to athletes and consumers around the world.
